# %% [markdown]
# <a href="https://colab.research.google.com/github/NunnaPooja/Car_Price_Estimator/blob/main/Car_Price_Estimator_LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv('quikr_car - quikr_car.csv')
#X= dataset(['Price']).drop()
#y=dataset(['Price'])

# %%
dataset.shape
# Out:
# (892, 6)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
dataset.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
backup= dataset.copy()

# %%
dataset['year'].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs',
#        'sale', '1995', 'ara)', '2002', 'SELL', '2001', 'tion', 'odel',
#        '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi', 'car', 'able', 'no.',
#        'd...', 'SALE', 'digo', 'sell', 'd Ex', 'n...', 'e...', 'D...',
#        ', Ac', 'go .', 'k...', 'o c4', 'zire', 'cent', 'Sumo', 'cab',
#        't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %%
dataset=dataset[dataset['year'].str.isnumeric()]
dataset['year']=dataset['year'].astype(int)

# %%
dataset['company'].unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Maruti', 'Ford', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'I', 'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat',
#        'Force', 'Mercedes', 'Land', 'Jaguar', 'Jeep', 'Volvo'],
#       dtype=object)

# %%
dataset['kms_driven'].unique()
# Out:
# array(['45,000 kms', '40 kms', '22,000 kms', '28,000 kms', '36,000 kms',
#        '59,000 kms', '41,000 kms', '25,000 kms', '24,530 kms',
#        '60,000 kms', '30,000 kms', '32,000 kms', '48,660 kms',
#        '4,000 kms', '16,934 kms', '43,000 kms', '35,550 kms',
#        '39,522 kms', '39,000 kms', '55,000 kms', '72,000 kms',
#        '15,975 kms', '70,000 kms', '23,452 kms', '35,522 kms',
#        '48,508 kms', '15,487 kms', '82,000 kms', '20,000 kms',
#        '68,000 kms', '38,000 kms', '27,000 kms', '33,000 kms',
#        '46,000 kms', '16,000 kms', '47,000 kms', '35,000 kms',
#        '30,874 kms', '15,000 kms', '29,685 kms', '1,30,000 kms',
#        '19,000 kms', nan, '54,000 kms', '13,000 kms', '38,200 kms',
#        '50,000 kms', '13,500 kms', '3,600 kms', '45,863 kms',
#        '60,500 kms', '12,500 kms', '18,000 kms', '13,349 kms',
#        '29,000 kms', '44,000 kms', '42,000 kms', '14,000 kms',
#        '49,000 kms', '36,200 kms', '51,000 kms', '1,04,000 kms',
# ...

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
print(dataset.columns)
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
dataset['kms_driven']=dataset['kms_driven'].str.split(' ').str.get(0).str.replace(',','')

# %% [markdown]
# kms_driven has nan values and value as petrol

# %%
dataset['kms_driven']=dataset['kms_driven'].str.isnumeric()

# %%
dataset['kms_driven'].unique()
# Out:
# array([True, nan, False], dtype=object)

# %%
dataset=dataset[~dataset['kms_driven'].isna()]

# %%
dataset['kms_driven']=dataset['kms_driven'].astype(int)
# Out:
# <ipython-input-529-4fd176f48c56>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['kms_driven']=dataset['kms_driven'].astype(int)

# %% [markdown]
# kms_driven sorted

# %%
dataset['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %%
dataset=dataset[~dataset['fuel_type'].isna()]

# %%
dataset['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'LPG'], dtype=object)

# %% [markdown]
# Data Cleaning
# 1. year has non-year values-remove them
# 2. year object to int
# 3. Price has ask for price componenet-remove them
# 4. Price has ,
# 5. Price object to int
# 6. kms_driven has nan values
# 7. kms_driven has ,
# 8. kms_driven has kms at the end -remove them
# 8. fuel_type has nan values
# 9. keep first 3 words of the company name

# %% [markdown]
# year-sorted

# %%
dataset['Price'].unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
dataset=dataset[dataset['Price']!='Ask For Price']
dataset['Price'].unique()
# Out:
# array(['80,000', '4,25,000', '3,25,000', '5,75,000', '1,75,000',
#        '1,90,000', '8,30,000', '2,50,000', '1,82,000', '3,15,000',
#        '4,15,000', '3,20,000', '10,00,000', '5,00,000', '3,50,000',
#        '1,60,000', '3,10,000', '75,000', '1,00,000', '2,90,000', '95,000',
#        '1,80,000', '3,85,000', '1,05,000', '6,50,000', '6,89,999',
#        '4,48,000', '5,49,000', '5,01,000', '4,89,999', '2,80,000',
#        '3,49,999', '2,84,999', '3,45,000', '4,99,999', '2,35,000',
#        '2,49,999', '14,75,000', '3,95,000', '2,20,000', '1,70,000',
#        '85,000', '2,00,000', '5,70,000', '1,10,000', '4,48,999',
#        '18,91,111', '1,59,500', '3,44,999', '4,49,999', '8,65,000',
#        '6,99,000', '3,75,000', '2,24,999', '12,00,000', '1,95,000',
#        '3,51,000', '2,40,000', '90,000', '1,55,000', '6,00,000',
#        '1,89,500', '2,10,000', '3,90,000', '1,35,000', '16,00,000',
#        '7,01,000', '2,65,000', '5,25,000', '3,72,000', '6,35,000',
# ...

# %% [markdown]
# remove , from price

# %%
type(dataset['Price'])
# Out:
# pandas.core.series.Series

# %%
dataset['Price']=dataset['Price'].str.replace(',','').astype(int)
# Out:
# <ipython-input-536-bb9a793f74a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Price']=dataset['Price'].str.replace(',','').astype(int)

# %%
dataset['Price']
# Out:
# 0       80000
# 1      425000
# 3      325000
# 4      575000
# 6      175000
#         ...
# 883    270000
# 885    110000
# 886    300000
# 888    260000
# 889    390000
# Name: Price, Length: 816, dtype: int64

# %%
dataset['Price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 816 entries, 0 to 889
# Series name: Price
# Non-Null Count  Dtype
# --------------  -----
# 816 non-null    int64
# dtypes: int64(1)
# memory usage: 12.8 KB

# %%
dataset['name']=dataset['name'].str.split().str.slice(start=0,stop=3).str.join(' ')

# %%
dataset['name']
# Out:
# 0         Hyundai Santro Xing
# 1         Mahindra Jeep CL550
# 3           Hyundai Grand i10
# 4      Ford EcoSport Titanium
# 6                   Ford Figo
#                 ...
# 883        Maruti Suzuki Ritz
# 885            Tata Indica V2
# 886      Toyota Corolla Altis
# 888              Tata Zest XM
# 889        Mahindra Quanto C8
# Name: name, Length: 816, dtype: object

# %% [markdown]
# dataset = dataset.reset_index(drop=True)
# is used to reset the index of a Pandas DataFrame. Here's what it does:
#
# 🔹 How It Works:
# Removes the current index and replaces it with a new default index (0, 1, 2, ...).
# drop=True ensures the old index is not added back as a column.
# The reset_index() function returns a new DataFrame, so it's important to assign it back to dataset.

# %%
dataset=dataset.reset_index(drop=True)

# %%
dataset
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000           1    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000           1    Diesel
# 2         Hyundai Grand i10   Hyundai  2014  325000           1    Petrol
# 3    Ford EcoSport Titanium      Ford  2014  575000           1    Diesel
# 4                 Ford Figo      Ford  2012  175000           1    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 811      Maruti Suzuki Ritz    Maruti  2011  270000           1    Petrol
# 812          Tata Indica V2      Tata  2009  110000           1    Diesel
# 813    Toyota Corolla Altis    Toyota  2009  300000           1    Petrol
# 814            Tata Zest XM      Tata  2018  260000           1    Diesel
# 815      Mahindra Quanto C8  Mahindra  2013  390000           1    Diesel
#
# [816 rows x 6 columns]

# %% [markdown]
# done with data cleaning
# now convert to csv file

# %%
dataset.to_csv('cleaned_car_data.csv')

# %%
dataset.describe(include='all')
# Out:
#                        name company         year         Price  kms_driven  \
# count                   816     816   816.000000  8.160000e+02       816.0
# unique                  254      25          NaN           NaN         NaN
# top     Maruti Suzuki Swift  Maruti          NaN           NaN         NaN
# freq                     51     221          NaN           NaN         NaN
# mean                    NaN     NaN  2012.444853  4.117176e+05         1.0
# std                     NaN     NaN     4.002992  4.751844e+05         0.0
# min                     NaN     NaN  1995.000000  3.000000e+04         1.0
# 25%                     NaN     NaN  2010.000000  1.750000e+05         1.0
# 50%                     NaN     NaN  2013.000000  2.999990e+05         1.0
# 75%                     NaN     NaN  2015.000000  4.912500e+05         1.0
# max                     NaN     NaN  2019.000000  8.500003e+06         1.0
#
#        fuel_type
# count        816
# unique         3
# ...

# %%
dataset[dataset['Price']>6000000]
# Out:
#                    name   company  year    Price  kms_driven fuel_type
# 534  Mahindra XUV500 W6  Mahindra  2014  8500003           1    Diesel

# %% [markdown]
# as there is an outlier we are going to remove such

# %%
dataset=dataset[dataset['Price']<6000000]

# %% [markdown]
# building model

# %%
X=dataset[['name','company','year','kms_driven','fuel_type']]
y=dataset[['Price']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Creating an OneHotEncoder object to contain all the possible categories

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %% [markdown]
# #### Creating a column transformer to transform categorical columns

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),
                                    remainder='passthrough')

# %% [markdown]
# #### Linear Regression Model

# %%
linear_regressor=LinearRegression()

# %% [markdown]
# ####making pipeline

# %%
pipe=make_pipeline(column_trans,linear_regressor)

# %% [markdown]
# Fitting model

# %%
pipe.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
# ...

# %%
y_pred=pipe.predict(X_test)

# %% [markdown]
# checking r2 score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7902722649176146

# %% [markdown]
# #### Finding the model with a random state of TrainTestSplit where the model was found to give highest r2_score(91.9)

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=i)
    linear_regressor=LinearRegression()
    pipe=make_pipeline(column_trans,linear_regressor)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 655

# %%
scores[np.argmax(scores)]
# Out:
# 0.9195578530076862

# %%
pipe.predict(pd.DataFrame(columns=X_test.columns,data=np.array(['Tata Aria Pleasure','Tata',2019,100,'Petrol']).reshape(1,5)))
# Out:
# array([[459031.01813229]])

# %% [markdown]
# best model is found at a certain random state

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.9195578530076862

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame(columns=['name','company','year','kms_driven','fuel_type'],data=np.array(['Tata Aria Pleasure','Tata',2019,100,'Petrol']).reshape(1,5)))
# Out:
# array([[347989.40277763]])

# %%
pipe.steps[0][1].transformers[0][1].categories[0]
# Out:
# array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#        'Chevrolet Beat LS', 'Chevrolet Beat LT', 'Chevrolet Beat PS',
#        'Chevrolet Cruze LTZ', 'Chevrolet Enjoy', 'Chevrolet Enjoy 1.4',
#        'Chevrolet Sail 1.2', 'Chevrolet Sail UVA', 'Chevrolet Spark',
#        'Chevrolet Spark 1.0', 'Chevrolet Spark LS', 'Chevrolet Spark LT',
#        'Chevrolet Tavera LS', 'Chevrolet Tavera Neo', 'Datsun GO T',
#        'Datsun Go Plus', 'Datsun Redi GO', 'Fiat Linea Emotion',
#        'Fiat Petra ELX', 'Fiat Punto Emotion', 'Force Motors Force',
#        'Force Motors One', 'Ford EcoSport', 'Ford EcoSport Ambiente',
#        'Ford EcoSport Titanium', 'Ford EcoSport Trend',
# ...
